# %% [markdown]
# # KRMU LLM Bootcamp — Deep Learning Assessment 1
#
# Fill in each section below. Do not delete the section headers — the grading checklist maps to them.

# %% [markdown]
# ## 1. Problem Formulation
#
# _Describe the task, the target variable, and why it's framed as classification/regression._

# %% [markdown]
# ## 2. Dataset Preparation

# %% [markdown]
# ## 3. Feature Engineering

# %% [markdown]
# ## 4. Class Imbalance Handling

# %% [markdown]
# ## 5. Model Building (PyTorch)

# %% [markdown]
# ## 6. Loss Function & Optimizer

# %% [markdown]
# ## 7. Training Loop

# %% [markdown]
# ## 8. Model Evaluation

# %% [markdown]
# ## 9. Save Model Parameters
